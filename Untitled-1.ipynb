# %% [markdown]
# #Dizionari

# %%
device = {"id": "A-1", "Location":"Room1"}
device
# Out:
# {'id': 'A-1', 'Location': 'Room1'}

# %% [markdown]
# #Lista di Dizionari

# %%
sensori = [ {"id": "A-1", "Location":"Room1"},
            {"id": "A-2", "Location":"Room2"},
            {"id": "A-3", "Location":"Room3"} ]
sensori[1]
# Out:
# {'id': 'A-2', 'Location': 'Room2'}

# %% [markdown]
# #Dizionari Annidati

# %%
info = {
    "Sensor": 
        {"Details": 
            {"Site": "b1", "Zone": "West"}
        }
    }
info["Sensor"]["Details"]["Site"]
# Out:
# 'b1'

# %% [markdown]
# #Condizioni

# %%
potenza = 50
if potenza > 50:
    x = "Alta"
else:
    x = "Normale"
    
x
# Out:
# 'Normale'

# %%
x = 3
if x > 3:
    print("Maggiore di 3")
elif x == 3:
    print("Uguale a 3")
else:
    print("Minore di 3")
# Out:
# Uguale a 3

# %% [markdown]
# #For

# %%
list = [10, 20, 30, 40, 50]
for x in list:
    print(x)
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# #For sui Dizionari

# %%
dizionario = {"A-1": "Room1",
     "A-2": "Room2"}
for chiave, valore in dizionario.items():
    print(chiave, valore)
# Out:
# A-1 Room1
# A-2 Room2

# %% [markdown]
# #Funzioni

# %%
def descrivi(tipo):
    return f"Dispositivo {tipo}"

descrivi("meter")
# Out:
# 'Dispositivo meter'

# %% [markdown]
# #F-string

# %%
tipo="battery"
site="c1"
f"{tipo}/{site}/file.json"
# Out:
# 'battery/b1/file.json'

# %% [markdown]
# #Date

# %%
from datetime import datetime
str="2024-06-15 14:30:00"
dt=datetime.fromisoformat(str)
dt
# Out:
# datetime.datetime(2024, 6, 15, 14, 30)

# %% [markdown]
# #Controllo di Appartenenza

# %%
"x" in ["a", "b", "c", "x", "y", "z"]
# Out:
# True

# %%
letture = []

def aggiungi(id, temp):
    letture.append({"id" : id, "temp": temp})
    
    
def media_temp():
    if not letture:
        return None
    return sum(x["temp"] for x in letture) / len(letture)
    

for _id, _temp in [(1, 31.1), (2, 29.8), (3, 30.5), (4, 32.0), (5, 28.9), (6, 30.2)]:
    aggiungi(_id, _temp)

print(media_temp())
# Out:
# [{'id': 1, 'temp': 31.1}, {'id': 2, 'temp': 29.8}, {'id': 3, 'temp': 30.5}, {'id': 4, 'temp': 32.0}, {'id': 5, 'temp': 28.9}, {'id': 6, 'temp': 30.2}]
# 30.416666666666668
